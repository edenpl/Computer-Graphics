# %% [markdown]
# GUÍA DE LABORATORIO 13

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %% [markdown]
# ### Cambien el tipo de color a RGB

# %%
img = cv2.imread('img.jpg')
plt.imshow(img)

# %% [markdown]
# conversión BGR -> RGB

# %%
#Leer una imagen
img = cv2.imread('img.jpg')

#Cambiar el espacio de color en img2
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Imprimo características de la imagen en su nuevo espacio de color
# alto, ancho y canales
print("alto, alto, canales = "+ str(img.shape))

#Muestro la imagen
plt.imshow(img)
# Out:
# alto, alto, canales = (683, 1024, 3)

# %% [markdown]
# conversión BGR -> RGBA

# %%
#Leer una imagen
img2 = cv2.imread('img.jpg')

#Cambiar el espacio de color en img2
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGBA)

#Imprimo características de la imagen en su nuevo espacio de color
# alto, ancho y canales
print("alto, alto, canales = "+ str(img2.shape))

#Muestro la imagen
plt.imshow(img2)
# Out:
# alto, alto, canales = (683, 1024, 4)

# %% [markdown]
# conversión BGR -> HLS

# %%
#Leer una imagen
img3 = cv2.imread('img.jpg')

#Cambiar el espacio de color en img3
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2HLS)

#Imprimo características de la imagen en su nuevo espacio de color
# alto, ancho y canales
print("alto, alto, canales = "+ str(img3.shape))

#Muestro la imagen
plt.imshow(img3)
# Out:
# alto, alto, canales = (683, 1024, 3)

# %% [markdown]
# conversión BGR -> YUV

# %%
#Leer una imagen
img3 = cv2.imread('img.jpg')

#Cambiar el espacio de color en img3
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2YUV)

#Imprimo características de la imagen en su nuevo espacio de color
# alto, ancho y canales
print("alto, alto, canales = "+ str(img3.shape))

#Muestro la imagen
plt.imshow(img3)
# Out:
# alto, alto, canales = (683, 1024, 3)

# %% [markdown]
# conversión BGR -> XYZ

# %%
#Leer una imagen
img3 = cv2.imread('img.jpg')

#Cambiar el espacio de color en img3
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2XYZ)

#Imprimo características de la imagen en su nuevo espacio de color
# alto, ancho y canales
print("alto, alto, canales = "+ str(img3.shape))

#Muestro la imagen
plt.imshow(img3)
# Out:
# alto, alto, canales = (683, 1024, 3)

# %% [markdown]
# ### Hagan girar una imagen

# %% [markdown]
# Primero se calculan las dimensiones del : ancho , alto  y el cento dela figura a rotar, luego se establece una matriz de rotación con el angulo a rotar, para luego usar una transformación con warpAffine, con los valores del ancho y la altura.

# %%
(altura, ancho)=img2.shape[:2] 
(cX, cY) = (ancho//2, altura//2) 

M = cv2.getRotationMatrix2D((cX, cY), 65, 1.0) 
rotacion = cv2.warpAffine(img2, M, (ancho, altura)) 
plt.imshow(rotacion)
plt.show()

# %%
img_r = img2
img_R180 = cv2.rotate(img_r, cv2.ROTATE_180)

# Rotamos la imagen

plt.imshow(img_R180)

# %% [markdown]
# ### Dibujen un círculo sobre las caras de dicha figura y agreguen un texto que describa que es (persona, perro, gato).

# %% [markdown]
# Circulo:
# Sintaxis:
# imgWC = cv2.circle(img_G,(850,110),100,(0,0,255),15,cv2.LINE_AA)
#
# - El primer argumento de la función circle() es la imagen que queremos dibujar del círculo.
#
# - El segundo argumento es el punto central del círculo, y su valor debe ser un punto que contenga los valores de los ejes x e y de un píxel que queremos usar como centro del círculo.
#
# - El tercer argumento es el radio del círculo y su valor puede ser cualquier número entero.
# El cuarto argumento es el color del círculo, y debe ser un valor de triplete BGR como (0,0,255) para el color rojo.
#
# Letra:
# Sintaxis:
#
#
#
# cv2.putText (imagen, texto, organización, fuente, escala de fuente, color [, grosor [, tipo de línea [, origen inferior izquierdo]]])
# Texto: cadena de texto que se va a dibujar.
#
# - Texto: cadena de texto que se va a dibujar
#
# - Organización: son las coordenadas de la esquina inferior izquierda de la cadena de texto en la imagen. Las coordenadas se representan como tuplas de dos valores, es decir ( valor de la coordenada X , valor de la coordenada Y ).
#
#
# - Fuente: Denota el tipo de fuente. Algunos tipos de fuentes son FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN, etc.
#
#
# - FontScale: factor de escala de fuente que se multiplica por el tamaño base específico de la fuente.
#
#
# - Color: es el color de la cadena de texto que se va a dibujar. Para BGR , pasamos una tupla. por ejemplo: (0,255,255) para el color amarillo.
#
#
# - Grosor: Es el grosor de la línea en px .

# %%
img_G = cv2.imread('img.jpeg')

img_G = cv2.cvtColor(img_G, cv2.COLOR_BGR2RGB)
#persona

imgWC = cv2.circle(img_G,(850,110),100,(0,0,255),15,cv2.LINE_AA)
cv2.putText(img_G,"Persona",(800,110),cv2.FONT_HERSHEY_COMPLEX,2,(0,0,255),3)
#gato

imgWC = cv2.circle(img_G,(500,380),80,(0,255,0),15,cv2.LINE_AA)

cv2.putText(img_G,"Gato",(450,380),cv2.FONT_HERSHEY_COMPLEX,2,(0,255,0),3)
#perro

imgWC = cv2.circle(img_G,(750,300),130,(255,0,0),15,cv2.LINE_AA)

cv2.putText(img_G,"Perro",(700,300),cv2.FONT_HERSHEY_COMPLEX,2,(255,0,0),3)

plt.imshow(imgWC)

# %% [markdown]
# ### Guarden la figura con los círculos dibujados y el texto generado

# %% [markdown]
# Se usa imwrite, el método se utiliza para guardar una imagen. Esto guardará la imagen según el formato especificado en el directorio de trabajo actual.

# %%
cv2.imwrite('Círculos y letras .jpg', cv2.cvtColor(img_G, cv2.COLOR_RGB2BGR))
# Out:
# True

# %% [markdown]
# ### En una imagen distinta al anterior creen una pentágono sobre las caras de las figuras y agreguen un texto que describa que es (persona, perro, gato).

# %%
img_G2 = cv2.imread('img_G2.jpg')
img_G2 = cv2.cvtColor(img_G2, cv2.COLOR_BGR2RGB)

def drawPentagono(img, x, y, tam, color) -> None:
    cv2.line(img, (x, y-tam), (x-tam, y-20), color, 5)
    cv2.line(img, (x-tam, y-20), (x-tam+20, y+tam), color, 5)
    cv2.line(img, (x-tam+20, y+tam), (x+tam-20, y+tam), color, 5)
    cv2.line(img, (x+tam-20, y+tam), (x+tam, y-20), color, 5)
    cv2.line(img, (x+tam, y-20), (x, y-tam), color, 5)
    
#persona
drawPentagono(img_G2, 400, 150, 130, (0,0,255))
cv2.putText(img_G2,"Persona",(300, 150),cv2.FONT_HERSHEY_COMPLEX,2,(0,0,255),3)


#gato

drawPentagono(img_G2, 230, 250, 80, (0,255,0))
cv2.putText(img_G2,"Gato",(150, 250),cv2.FONT_HERSHEY_COMPLEX,2,(0,255,0),3)

#perro
drawPentagono(img_G2, 600, 200, 80, (255,0,0))
cv2.putText(img_G2,"Perro",(550, 200),cv2.FONT_HERSHEY_COMPLEX,2,(255,0,0),3)
plt.imshow(img_G2)

# %% [markdown]
# ### Guarden la figura con los círculos dibujados y el texto generado

# %% [markdown]
# Se usa imwrite, el método se utiliza para guardar una imagen. Esto guardará la imagen según el formato especificado en el directorio de trabajo actual.

# %%
cv2.imwrite('Polígonos y letras .jpg', cv2.cvtColor(img_G2, cv2.COLOR_RGB2BGR))
# Out:
# True

# %% [markdown]
# ### Creen un programa que permita dibujar diferentes tipos de figuras geométricas con el uso de eventos de mouse para poder hacer dibujos y luego guarden la imagen.

# %%
import numpy as np
import cv2


def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),100,(255,0,0),-1)
        

def draw_rectangle(event,x,y,flags,param):
    global ix,iy
    if event == cv2.EVENT_LBUTTONDOWN:
        ix,iy=x,y
    elif event == cv2.EVENT_LBUTTONUP:
        cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)

def draw_line(event,x,y,flags,param):
    global ix,iy
    if event == cv2.EVENT_LBUTTONDOWN:
        ix,iy=x,y
    elif event == cv2.EVENT_LBUTTONUP:
        cv2.line(img,(ix,iy),(x,y),(255,0,0),5)

        
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while(1):
    cv2.imshow('image',img)
    k = cv2.waitKey(20) & 0xFF
    if k == 27:
        break
    elif k == ord('c'):
        cv2.setMouseCallback('image',draw_circle)
    elif k == ord('r'):
        cv2.setMouseCallback('image',draw_rectangle)
    elif k == ord('l'):
        cv2.setMouseCallback('image',draw_line)
    elif k == ord('d'):
        cv2.setMouseCallback('image',dibujo_draw_circle)

        
cv2.destroyAllWindows()

# %%
cv2.imwrite('img.jpg', img)

# %% [markdown]
# ### Modifiquen el programa para agregar funciones adicionales.

# %%
import numpy as np
import cv2

def dibujo_draw_circle(event, x, y, flags, param):
    global ix, iy, dibujar
    cv2.putText(img,"Dibujo",(100, 400),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    if event == cv2.EVENT_LBUTTONDOWN: #Si se presiona el botón izquierdo del mouse
        ix, iy = x, y
        dibujar = True
        
    elif event == cv2.EVENT_MOUSEMOVE: #Si se mueve el mouse
        if dibujar == True:
            cv2.circle(img, (x, y), 20, (38, 83, 242), -1)
            
    elif event == cv2.EVENT_LBUTTONUP: #Si se suelta el botón izquierdo del mouse
        dibujar = False
        cv2.circle(img, (x, y), 20, (38, 83, 242), -1)

def draw_circle(event,x,y,flags,param):
    cv2.putText(img,"Circulo",(200, 300),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    if event == cv2.EVENT_LBUTTONDBLCLK:
        cv2.circle(img,(x,y),100,(255,0,0),-1)

def draw_rectangle(event,x,y,flags,param):
    global ix,iy
    cv2.putText(img,"Rectangulo",(300, 200),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    if event == cv2.EVENT_LBUTTONDOWN:
        ix,iy=x,y
    elif event == cv2.EVENT_LBUTTONUP:
        cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)

def draw_line(event,x,y,flags,param):
    
    global ix,iy
    cv2.putText(img,"Linea",(400, 150),cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    if event == cv2.EVENT_LBUTTONDOWN:
        ix,iy=x,y
    elif event == cv2.EVENT_LBUTTONUP:
        cv2.line(img,(ix,iy),(x,y),(0,0,255),5)


        
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while(1):
    cv2.imshow('image',img)
    k = cv2.waitKey(20) & 0xFF
    if k == 27:
        break
    elif k == ord('c'):
        cv2.setMouseCallback('image',draw_circle)
    elif k == ord('r'):
        cv2.setMouseCallback('image',draw_rectangle)
    elif k == ord('l'):
        cv2.setMouseCallback('image',draw_line)
    elif k == ord('d'):
        cv2.setMouseCallback('image',dibujo_draw_circle)

        
cv2.destroyAllWindows()

# %%
cv2.imwrite('img.jpg', img)
